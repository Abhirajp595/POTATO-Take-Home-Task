# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('correct_twitter_202102.tsv',sep='\t')
df.head()
# Out:
# C:\Users\abhir\AppData\Local\Temp\ipykernel_8708\3178179834.py:1: DtypeWarning: Columns (0,4,5,7,8,9,10,11,12,13,20,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('correct_twitter_202102.tsv',sep='\t')
#                     id           event                               ts1  \
# 0  1358322479136178177  britney_202102  2022-03-01 09:06:52.403595-05:00
# 1  1358323016736796677  britney_202102  2022-01-05 08:34:04.477789-05:00
# 2  1358322996696465409  britney_202102  2022-03-01 09:06:52.399008-05:00
# 3  1358322976769286151  britney_202102  2022-03-01 09:06:52.399205-05:00
# 4  1368923802260889606  britney_202102  2022-03-01 07:26:05.505986-05:00
#
#                                 ts2 from_stream directly_from_stream  \
# 0  2022-03-01 09:06:52.403595-05:00        True                 True
# 1  2022-03-01 09:06:52.398778-05:00        True                 True
# 2  2022-03-01 09:06:52.399008-05:00        True                 True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845730 entries, 0 to 845729
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   id                             845730 non-null  object
#  1   event                          845730 non-null  object
#  2   ts1                            845730 non-null  object
#  3    ts2                           845730 non-null  object
#  4   from_stream                    845730 non-null  object
#  5   directly_from_stream           845730 non-null  object
#  6   from_search                    845730 non-null  bool
#  7   directly_from_search           845730 non-null  object
#  8   from_quote_search              845730 non-null  object
#  9   directly_from_quote_search     845730 non-null  object
#  10  from_convo_search              845730 non-null  object
#  11  directly_from_convo_search     845730 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# event                                 0
# ts1                                   0
#  ts2                                  0
# from_stream                           0
# directly_from_stream                  0
# from_search                           0
# directly_from_search                  0
# from_quote_search                     0
# directly_from_quote_search            0
# from_convo_search                     0
# directly_from_convo_search            0
# from_timeline_search                  0
# directly_from_timeline_search         0
# text                                  3
# lang                               3011
# author_id                          3012
# author_handle                      3012
# created_at                         3012
# conversation_id                    3012
# possibly_sensitive                 3012
# reply_settings                     3012
# source                             3012
# ...

# %%
df.describe()
# Out:
#           author_id  conversation_id  author_follower_count  retweet_count  \
# count  8.427180e+05     8.427180e+05           8.427180e+05  842718.000000
# mean   4.485312e+17     1.361256e+18           3.512069e+04    5131.003708
# std    5.534232e+17     9.692204e+15           8.581543e+05   13196.765737
# min    7.620000e+02     1.317056e+09           0.000000e+00       0.000000
# 25%    2.600190e+08     1.358203e+18           1.810000e+02       3.000000
# 50%    2.654599e+09     1.360221e+18           4.980000e+02     210.000000
# 75%    1.052283e+18     1.365381e+18           1.331000e+03    2236.000000
# max    1.376950e+18     1.377048e+18           1.310843e+08  661268.000000
#
#          reply_count    like_count    quote_count    replied_to  \
# count  842718.000000  8.427180e+05  842718.000000  4.831500e+04
# mean        6.753562  1.267377e+02       6.110735  1.360149e+18
# std       501.819952  6.294110e+03     336.081434  2.466743e+16
# ...

# %%
def search_term_analysis_v2(df, term):
    # Filter the tweets containing the term (case insensitive)
    filtered_df = df[df['text'].str.contains(term, case=False, na=False)]

    # Convert 'created_at' to datetime if it's not already
    filtered_df['created_at'] = pd.to_datetime(filtered_df['created_at'], errors='coerce')

    # Handle the case where no tweets contain the term
    if filtered_df.empty:
        return {
            'tweets_per_day': "No tweets found",
            'unique_users': 0,
            'avg_likes': 0,
            'tweet_locations': "No locations found",
            'tweets_per_hour': "No data available",
            'top_user': "No user found"
        }

    # 1. Number of tweets per day
    filtered_df['date'] = filtered_df['created_at'].dt.date
    tweets_per_day = filtered_df.groupby('date').size()

    # 2. Number of unique users who posted tweets containing the term
    unique_users = filtered_df['author_id'].nunique()

    # 3. Average likes for tweets containing the term
    avg_likes = filtered_df['like_count'].mean()

    # 4. Location (place_id) of tweets
    tweet_locations = filtered_df['place_id'].value_counts()

    # 5. Time of day tweets were posted
    filtered_df['hour'] = filtered_df['created_at'].dt.hour
    tweets_per_hour = filtered_df.groupby('hour').size()

    # 6. User who posted the most tweets containing the term
    top_user = filtered_df['author_handle'].value_counts().idxmax()

    return {
        'tweets_per_day': tweets_per_day.to_dict(),
        'unique_users': unique_users,
        'avg_likes': avg_likes,
        'tweet_locations': tweet_locations.to_dict(),
        'tweets_per_hour': tweets_per_hour.to_dict(),
        'top_user': top_user
    }

# Example call with a term (e.g., 'music')
results_v2 = search_term_analysis_v2(df, 'music')
results_v2
# Out:
# {'tweets_per_day': {datetime.date(2021, 1, 1): 77,
#   datetime.date(2021, 1, 2): 205,
#   datetime.date(2021, 1, 3): 134,
#   datetime.date(2021, 1, 4): 74,
#   datetime.date(2021, 1, 5): 98,
#   datetime.date(2021, 1, 6): 56,
#   datetime.date(2021, 1, 7): 52,
#   datetime.date(2021, 1, 8): 169,
#   datetime.date(2021, 1, 9): 148,
#   datetime.date(2021, 1, 10): 74,
#   datetime.date(2021, 1, 11): 51,
#   datetime.date(2021, 1, 12): 107,
#   datetime.date(2021, 1, 13): 175,
#   datetime.date(2021, 1, 14): 71,
#   datetime.date(2021, 1, 15): 170,
#   datetime.date(2021, 1, 16): 125,
#   datetime.date(2021, 1, 17): 67,
#   datetime.date(2021, 1, 18): 56,
#   datetime.date(2021, 1, 19): 46,
#   datetime.date(2021, 1, 20): 68,
#   datetime.date(2021, 1, 21): 202,
#   datetime.date(2021, 1, 22): 362,
#   datetime.date(2021, 1, 23): 207,
#   datetime.date(2021, 1, 24): 116,
#   datetime.date(2021, 1, 25): 229,
#   datetime.date(2021, 1, 26): 114,
#   datetime.date(2021, 1, 27): 125,
# ...

# %%
from flask import Flask, request, jsonify
import pandas as pd

app = Flask(__name__)

# Load data (adjust path if needed)
data = pd.read_csv('correct_twitter_202102.tsv', sep='\t')

# Function to search for a term and generate aggregate results
def search_term_analysis(df, term):
    filtered_df = df[df['text'].str.contains(term, case=False, na=False)]
    if filtered_df.empty:
        return {
            'tweets_per_day': "No tweets found",
            'unique_users': 0,
            'avg_likes': 0,
            'tweet_locations': "No locations found",
            'tweets_per_hour': "No data available",
            'top_user': "No user found"
        }

    filtered_df['date'] = pd.to_datetime(filtered_df['created_at']).dt.date
    tweets_per_day = filtered_df.groupby('date').size()
    unique_users = filtered_df['author_id'].nunique()
    avg_likes = filtered_df['like_count'].mean()
    tweet_locations = filtered_df['place_id'].value_counts()
    filtered_df['hour'] = pd.to_datetime(filtered_df['created_at']).dt.hour
    tweets_per_hour = filtered_df.groupby('hour').size()
    top_user = filtered_df['author_handle'].value_counts().idxmax()

    return {
        'tweets_per_day': tweets_per_day.to_dict(),
        'unique_users': unique_users,
        'avg_likes': avg_likes,
        'tweet_locations': tweet_locations.to_dict(),
        'tweets_per_hour': tweets_per_hour.to_dict(),
        'top_user': top_user
    }

# API endpoint to handle search queries
@app.route('/search', methods=['GET'])
def search():
    term = request.args.get('term', '')
    if not term:
        return jsonify({'error': 'No search term provided'}), 400

    results = search_term_analysis(data, term)
    return jsonify(results)

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.43.75:5000
# Press CTRL+C to quit
# 192.168.43.75 - - [26/Sep/2024 15:08:30] "GET / HTTP/1.1" 404 -
# 192.168.43.75 - - [26/Sep/2024 15:08:30] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [26/Sep/2024 15:08:37] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [26/Sep/2024 15:08:37] "GET /favicon.ico HTTP/1.1" 404 -
